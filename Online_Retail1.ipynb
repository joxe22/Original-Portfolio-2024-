# %% [markdown]
# ## Online Retail (EDA)<a href="#Online-Retail-(EDA)" class="anchor-link">¶</a>
#
# In \[ \]:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
# In \[ \]:
#
#     file_path = '/Users/josethorex/Desktop/CO2WZWHLQ3GpXlr5Rkeq4w_6bb40d853b58401ebd85f554991bc2f1_online_retail/Online Retail.xlsx'
#     df = pd.read_excel(file_path)
#
# In \[ \]:
#
#     df.head()
#
# Out\[ \]:
#
# |     | InvoiceNo | StockCode | Description                         | Quantity | InvoiceDate         | UnitPrice | CustomerID | Country        |
# |-----|-----------|-----------|-------------------------------------|----------|---------------------|-----------|------------|----------------|
# | 0   | 536365    | 85123A    | WHITE HANGING HEART T-LIGHT HOLDER  | 6        | 2010-12-01 08:26:00 | 2.55      | 17850.0    | United Kingdom |
# | 1   | 536365    | 71053     | WHITE METAL LANTERN                 | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 2   | 536365    | 84406B    | CREAM CUPID HEARTS COAT HANGER      | 8        | 2010-12-01 08:26:00 | 2.75      | 17850.0    | United Kingdom |
# | 3   | 536365    | 84029G    | KNITTED UNION FLAG HOT WATER BOTTLE | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 4   | 536365    | 84029E    | RED WOOLLY HOTTIE WHITE HEART.      | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
#
# In \[ \]:
#
#     df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 541909 entries, 0 to 541908
#     Data columns (total 8 columns):
#      #   Column       Non-Null Count   Dtype
#     ---  ------       --------------   -----
#      0   InvoiceNo    541909 non-null  object
#      1   StockCode    541909 non-null  object
#      2   Description  540455 non-null  object
#      3   Quantity     541909 non-null  int64
#      4   InvoiceDate  541909 non-null  datetime64[ns]
#      5   UnitPrice    541909 non-null  float64
#      6   CustomerID   406829 non-null  float64
#      7   Country      541909 non-null  object
#     dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
#     memory usage: 33.1+ MB
#
# In \[ \]:
#
#     df.describe()
#
# Out\[ \]:
#
# |       | Quantity      | InvoiceDate                   | UnitPrice     | CustomerID    |
# |-------|---------------|-------------------------------|---------------|---------------|
# | count | 541909.000000 | 541909                        | 541909.000000 | 406829.000000 |
# | mean  | 9.552250      | 2011-07-04 13:34:57.156386048 | 4.611114      | 15287.690570  |
# | min   | -80995.000000 | 2010-12-01 08:26:00           | -11062.060000 | 12346.000000  |
# | 25%   | 1.000000      | 2011-03-28 11:34:00           | 1.250000      | 13953.000000  |
# | 50%   | 3.000000      | 2011-07-19 17:17:00           | 2.080000      | 15152.000000  |
# | 75%   | 10.000000     | 2011-10-19 11:27:00           | 4.130000      | 16791.000000  |
# | max   | 80995.000000  | 2011-12-09 12:50:00           | 38970.000000  | 18287.000000  |
# | std   | 218.081158    | NaN                           | 96.759853     | 1713.600303   |
#
# In \[ \]:
#
#     # Handling missing values
#     df.dropna(inplace=True)
#     df.head()
#
# Out\[ \]:
#
# |     | InvoiceNo | StockCode | Description                         | Quantity | InvoiceDate         | UnitPrice | CustomerID | Country        |
# |-----|-----------|-----------|-------------------------------------|----------|---------------------|-----------|------------|----------------|
# | 0   | 536365    | 85123A    | WHITE HANGING HEART T-LIGHT HOLDER  | 6        | 2010-12-01 08:26:00 | 2.55      | 17850.0    | United Kingdom |
# | 1   | 536365    | 71053     | WHITE METAL LANTERN                 | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 2   | 536365    | 84406B    | CREAM CUPID HEARTS COAT HANGER      | 8        | 2010-12-01 08:26:00 | 2.75      | 17850.0    | United Kingdom |
# | 3   | 536365    | 84029G    | KNITTED UNION FLAG HOT WATER BOTTLE | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 4   | 536365    | 84029E    | RED WOOLLY HOTTIE WHITE HEART.      | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
#
# In \[ \]:
#
#     # Droping columns
#
#     columnas_a_eliminar = ['Description', 'InvoiceNo', 'StockCode']
#     df.drop(columnas_a_eliminar, axis=1, inplace=True)
#     df.head()
#
# Out\[ \]:
#
# |     | Quantity | InvoiceDate         | UnitPrice | CustomerID | Country        |
# |-----|----------|---------------------|-----------|------------|----------------|
# | 0   | 6        | 2010-12-01 08:26:00 | 2.55      | 17850.0    | United Kingdom |
# | 1   | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 2   | 8        | 2010-12-01 08:26:00 | 2.75      | 17850.0    | United Kingdom |
# | 3   | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
# | 4   | 6        | 2010-12-01 08:26:00 | 3.39      | 17850.0    | United Kingdom |
#
# In \[ \]:
#
#     df['Country'].unique()
#
# Out\[ \]:
#
#     array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#            'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#            'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#            'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#            'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#            'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#            'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#            'Malta', 'RSA'], dtype=object)
#
# #### Exploring the basic statistics of this Dataset<a href="#Exploring-the-basic-statistics-of-this-Dataset" class="anchor-link">¶</a>
#
# includin:
#
# 1.  Mean
# 2.  Median
# 3.  Mode
#
# In \[ \]:
#
#     #Exploring the basic statistics of the dataset
#     # Excluir la columna "country" si es de tipo objeto
#     data_numeric = df.select_dtypes(include=[np.number])
#
#     # Paso 3: Medidas de Tendencia Central
#     mean_values = data_numeric.mean()
#     median_values = data_numeric.median()
#
#     # Moda puede tener múltiples valores, así que obtenemos todos los modos si existen
#     mode_values = data_numeric.mode(axis=0, dropna=True).iloc[0]
#
#
#     print("\nMean of the variables:")
#     print(mean_values)
#
#     print("\nMedian of the variables:")
#     print(median_values)
#
#     print("\nMode of the variables:")
#     print(mode_values)
#
#     Mean of the variables:
#     Quantity         12.061303
#     UnitPrice         3.460471
#     CustomerID    15287.690570
#     dtype: float64
#
#     Median of the variables:
#     Quantity          5.00
#     UnitPrice         1.95
#     CustomerID    15152.00
#     dtype: float64
#
#     Mode of the variables:
#     Quantity          1.00
#     UnitPrice         1.25
#     CustomerID    17841.00
#     Name: 0, dtype: float64
#
# In \[ \]:
#
#     #Medidas de Dispersión
#     std_dev_values = data_numeric.std()
#     range_values = data_numeric.max() - data_numeric.min()
#
#     print("\nDesviaciones estándar de las variables:")
#     print(std_dev_values)
#
#     print("\nRangos de las variables:")
#     print(range_values)
#
#     Desviaciones estándar de las variables:
#     Quantity       248.693370
#     UnitPrice       69.315162
#     CustomerID    1713.600303
#     dtype: float64
#
#     Rangos de las variables:
#     Quantity      161990.0
#     UnitPrice      38970.0
#     CustomerID      5941.0
#     dtype: float64
#
# In \[ \]:
#
#     # QUANTITY HISTOGRAM
#     plt.figure(figsize=(8, 5))
#     sns.histplot(data_numeric['Quantity'], bins=30, kde=True)
#     plt.title('Quantity Histogram')
#     plt.show()
#
#     /Users/josethorex/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#       with pd.option_context('mode.use_inf_as_na', True):
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[ \]:
#
#     # UNIT PRICE HISTOGRAM
#     plt.figure(figsize=(8, 5))
#     sns.histplot(data_numeric['UnitPrice'], bins=30, kde=True)
#     plt.title('UnitPrice Histogram')
#     plt.show()
#
#     /Users/josethorex/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#       with pd.option_context('mode.use_inf_as_na', True):
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### Performing Data Visualization to gain insights<a href="#Performing-Data-Visualization-to-gain-insights" class="anchor-link">¶</a>
#
# In \[ \]:
#
#     # Ejemplo de Histograma para una variable
#     plt.figure(figsize=(8, 5))
#     sns.histplot(data_numeric['UnitPrice'], bins=30, kde=True)
#     plt.title('Unit Price Histogram')
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.show()
#
#     /Users/josethorex/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#       with pd.option_context('mode.use_inf_as_na', True):
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[ \]:
#
#     # Scatter plot to show how relationship between variables is
#
#     plt.figure(figsize=(8, 5))
#     sns.scatterplot(x='Quantity', y='UnitPrice', data=data_numeric)
#     plt.title('Scatter Plot between Quantity & UnitPrice')
#     plt.xlabel('Quantity')
#     plt.ylabel('UnitPrice')
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[ \]:
#
#     data_numeric[['UnitPrice', 'Quantity']].corr()
#
# Out\[ \]:
#
# |           | UnitPrice | Quantity  |
# |-----------|-----------|-----------|
# | UnitPrice | 1.000000  | -0.001238 |
# | Quantity  | -0.001238 | 1.000000  |
#
# In \[ \]:
#
#     # Box plot para identificar outliers en 'unitprice'
#     plt.figure(figsize=(8, 5))
#     sns.boxplot(x=data_numeric['UnitPrice'])
#     plt.title('Box Plot of Unit Price')
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### NEXT TASK<a href="#NEXT-TASK" class="anchor-link">¶</a>
#
# Identify any outliers or anomalies in the dataset and discuss their
# potential impact on the analysis.
#
# In \[ \]:
#
#     # Calcular el rango intercuartílico (IQR)
#     Q1 = data_numeric['UnitPrice'].quantile(0.25)
#     Q3 = data_numeric['UnitPrice'].quantile(0.75)
#     IQR = Q3 - Q1
#
#     # Identificar outliers
#     outliers = (data_numeric['UnitPrice'] < (Q1 - 1.5 * IQR)) | (data_numeric['UnitPrice'] > (Q3 + 1.5 * IQR))
#
#     # Filtrar datos sin outliers
#     data_no_outliers = data_numeric[~outliers]
#     IQR
#
# Out\[ \]:
#
#     2.5
#
# In \[ \]:
#
#     #corregir los valores negativos en 'Quantity'
#     df.loc[df['Quantity'] < 0, 'Quantity'] = 0
#
# In \[ \]:
#
#     # Eliminar filas con 'UnitPrice' mayor que 3 veces la desviación estándar
#     df = df[df['UnitPrice'] <= df['UnitPrice'].mean() + 3 * df['UnitPrice'].std()]
#
# In \[ \]:
#
#     # Imputar valores atípicos en 'UnitPrice' con la mediana
#     median_price = df['UnitPrice'].median()
#     df.loc[df['UnitPrice'] > df['UnitPrice'].mean() + 3 * df['UnitPrice'].std(), 'UnitPrice'] = median_price
#
# In \[ \]:
#
#     # Aplicar escala logarítmica a 'UnitPrice'
#     import numpy as np
#     df['UnitPrice'] = np.log1p(df['UnitPrice'])
#
# In \[ \]:
#
#     # Eliminar filas con 'Quantity' mayor que 3 veces la desviación estándar
#     df = df[df['Quantity'] <= df['Quantity'].mean() + 3 * df['Quantity'].std()]
#
# In \[ \]:
#
#     # Imputar valores atípicos en 'Quantity' con la mediana
#     median_price = df['Quantity'].median()
#     df.loc[df['Quantity'] > df['Quantity'].mean() + 3 * df['Quantity'].std(), 'Quantity'] = median_price
#
# In \[ \]:
#
#     # Aplicar escala logarítmica a 'Quantity'
#     import numpy as np
#     df['Quantity'] = np.log1p(df['Quantity'])
#
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/433141796.py:3: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       df['Quantity'] = np.log1p(df['Quantity'])
#
# In \[ \]:
#
#     df
#
# Out\[ \]:
#
# |        | Quantity | InvoiceDate         | UnitPrice | CustomerID | Country        |
# |--------|----------|---------------------|-----------|------------|----------------|
# | 0      | 1.945910 | 2010-12-01 08:26:00 | 1.266948  | 17850.0    | United Kingdom |
# | 1      | 1.945910 | 2010-12-01 08:26:00 | 1.479329  | 17850.0    | United Kingdom |
# | 2      | 2.197225 | 2010-12-01 08:26:00 | 1.321756  | 17850.0    | United Kingdom |
# | 3      | 1.945910 | 2010-12-01 08:26:00 | 1.479329  | 17850.0    | United Kingdom |
# | 4      | 1.945910 | 2010-12-01 08:26:00 | 1.479329  | 17850.0    | United Kingdom |
# | ...    | ...      | ...                 | ...       | ...        | ...            |
# | 541904 | 2.564949 | 2011-12-09 12:50:00 | 0.615186  | 12680.0    | France         |
# | 541905 | 1.945910 | 2011-12-09 12:50:00 | 1.131402  | 12680.0    | France         |
# | 541906 | 1.609438 | 2011-12-09 12:50:00 | 1.638997  | 12680.0    | France         |
# | 541907 | 1.609438 | 2011-12-09 12:50:00 | 1.638997  | 12680.0    | France         |
# | 541908 | 1.386294 | 2011-12-09 12:50:00 | 1.783391  | 12680.0    | France         |
#
# 406291 rows × 5 columns
#
# ### NEXT TASK:<a href="#NEXT-TASK:" class="anchor-link">¶</a>
#
# Analyze the sales trends over time. Identify the busiest months and days
# of the week in terms of sales.
#
# In \[ \]:
#
#     data_no_outliers['InvoiceDate'] = df['InvoiceDate']
#
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/574318526.py:1: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_no_outliers['InvoiceDate'] = df['InvoiceDate']
#
# In \[ \]:
#
#     data_no_outliers['Country'] = df['Country']
#
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/3673659957.py:1: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_no_outliers['Country'] = df['Country']
#
# In \[ \]:
#
#     file_path = '/Users/josethorex/Desktop/CO2WZWHLQ3GpXlr5Rkeq4w_6bb40d853b58401ebd85f554991bc2f1_online_retail/Online Retail.xlsx'
#     df2 = pd.read_excel(file_path)
#
# In \[ \]:
#
#     data_no_outliers['Description'] = df2['Description']
#
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/1545324141.py:1: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_no_outliers['Description'] = df2['Description']
#
# In \[ \]:
#
#     # Paso 4: Crear columnas adicionales para mes y día de la semana
#     data_no_outliers['month'] = data_no_outliers['InvoiceDate'].dt.month
#     data_no_outliers['days'] = data_no_outliers['InvoiceDate'].dt.dayofweek
#     data_no_outliers
#
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/504427388.py:2: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_no_outliers['month'] = data_no_outliers['InvoiceDate'].dt.month
#     /var/folders/v7/j0z8x01j2sjfr3xgq_b0fw700000gn/T/ipykernel_38993/504427388.py:3: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame.
#     Try using .loc[row_indexer,col_indexer] = value instead
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       data_no_outliers['days'] = data_no_outliers['InvoiceDate'].dt.dayofweek
#
# Out\[ \]:
#
# |        | Quantity | UnitPrice | CustomerID | InvoiceDate         | month | days | Country        | Description                         |
# |--------|----------|-----------|------------|---------------------|-------|------|----------------|-------------------------------------|
# | 0      | 6        | 2.55      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | WHITE HANGING HEART T-LIGHT HOLDER  |
# | 1      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | WHITE METAL LANTERN                 |
# | 2      | 8        | 2.75      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | CREAM CUPID HEARTS COAT HANGER      |
# | 3      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | KNITTED UNION FLAG HOT WATER BOTTLE |
# | 4      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | RED WOOLLY HOTTIE WHITE HEART.      |
# | ...    | ...      | ...       | ...        | ...                 | ...   | ...  | ...            | ...                                 |
# | 541904 | 12       | 0.85      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | PACK OF 20 SPACEBOY NAPKINS         |
# | 541905 | 6        | 2.10      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDREN'S APRON DOLLY GIRL         |
# | 541906 | 4        | 4.15      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDRENS CUTLERY DOLLY GIRL        |
# | 541907 | 4        | 4.15      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDRENS CUTLERY CIRCUS PARADE     |
# | 541908 | 3        | 4.95      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | BAKING SET 9 PIECE RETROSPOT        |
#
# 370778 rows × 8 columns
#
# In \[ \]:
#
#     # Paso 5: Visualización de Tendencias Mensuales
#     plt.figure(figsize=(12, 6))
#     monthly_sales = data_no_outliers.resample('M', on='InvoiceDate').sum()
#     sns.lineplot(x=monthly_sales.index, y='UnitPrice', data=monthly_sales, label='Monthly Sales')
#     plt.title('Monthly Sales Trends')
#     plt.xlabel('Date')
#     plt.ylabel('Sales')
#     plt.show()
#
#     /Users/josethorex/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#       with pd.option_context('mode.use_inf_as_na', True):
#     /Users/josethorex/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#       with pd.option_context('mode.use_inf_as_na', True):
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# #### Identifying frecuent months<a href="#Identifying-frecuent-months" class="anchor-link">¶</a>
#
# In \[ \]:
#
#     monthly_sales = data_no_outliers.groupby('month')['UnitPrice'].sum()
#     busiest_month = monthly_sales.idxmax()
#     print(f"The most active month in terms of sales, is the month {busiest_month}.")
#
#     The most active month in terms of sales, is the month 11.
#
# In \[ \]:
#
#     # The most active days of the week
#     day_of_week_sales = data_no_outliers.groupby('days')['UnitPrice'].sum()
#     busiest_day_of_week = day_of_week_sales.idxmax()
#     print(f"The most active day in terms of sales, is the day {busiest_day_of_week}.")
#
#     The most active day in terms of sales, is the day 3.
#
# ## NEXT TASK<a href="#NEXT-TASK" class="anchor-link">¶</a>
#
# Explore the top-selling products and countries based on the quantity
# sold.
#
# In \[ \]:
#
#     data_no_outliers
#
# Out\[ \]:
#
# |        | Quantity | UnitPrice | CustomerID | InvoiceDate         | month | days | Country        | Description                         |
# |--------|----------|-----------|------------|---------------------|-------|------|----------------|-------------------------------------|
# | 0      | 6        | 2.55      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | WHITE HANGING HEART T-LIGHT HOLDER  |
# | 1      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | WHITE METAL LANTERN                 |
# | 2      | 8        | 2.75      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | CREAM CUPID HEARTS COAT HANGER      |
# | 3      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | KNITTED UNION FLAG HOT WATER BOTTLE |
# | 4      | 6        | 3.39      | 17850.0    | 2010-12-01 08:26:00 | 12    | 2    | United Kingdom | RED WOOLLY HOTTIE WHITE HEART.      |
# | ...    | ...      | ...       | ...        | ...                 | ...   | ...  | ...            | ...                                 |
# | 541904 | 12       | 0.85      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | PACK OF 20 SPACEBOY NAPKINS         |
# | 541905 | 6        | 2.10      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDREN'S APRON DOLLY GIRL         |
# | 541906 | 4        | 4.15      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDRENS CUTLERY DOLLY GIRL        |
# | 541907 | 4        | 4.15      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | CHILDRENS CUTLERY CIRCUS PARADE     |
# | 541908 | 3        | 4.95      | 12680.0    | 2011-12-09 12:50:00 | 12    | 4    | France         | BAKING SET 9 PIECE RETROSPOT        |
#
# 370778 rows × 8 columns
#
# In \[ \]:
#
#     # Agrupa por producto y calcula la cantidad total vendida
#     top_products = data_no_outliers.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
#
#     # Agrupa por país y calcula la cantidad total vendida
#     top_countries = data_no_outliers.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10)
#
#     # Visualización de los productos más vendidos
#     plt.figure(figsize=(12, 6))
#     sns.barplot(x=top_products.values, y=top_products.index, palette='viridis')
#     plt.title('Top-selling Products')
#     plt.xlabel('Total Quantity Sold')
#     plt.ylabel('Product')
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[ \]:
#
#     # Visualización de los países con más ventas
#     plt.figure(figsize=(12, 6))
#     sns.barplot(x=top_countries.values, y=top_countries.index, palette='mako')
#     plt.title('Top 10 Countries with More Sales')
#     plt.xlabel('Total Quantity Sold')
#     plt.ylabel('Country')
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### NEXT TASK<a href="#NEXT-TASK" class="anchor-link">¶</a>
#
# Identify any outliers or anomalies in the dataset and discuss their
# potential impact on the analysis.
#
# In \[ \]:
#
#     # Box plot para 'unitprice'
#     plt.figure(figsize=(8, 5))
#     sns.boxplot(x=df['UnitPrice'])
#     plt.title('Unit Price BoxPlot')
#     plt.show()
#
#     # Calcular el rango intercuartílico (IQR) para 'unitprice'
#     Q1_unitprice = df['UnitPrice'].quantile(0.25)
#     Q3_unitprice = df['UnitPrice'].quantile(0.75)
#     IQR_unitprice = Q3_unitprice - Q1_unitprice
#
#     # Identificar outliers en 'unitprice'
#     outliers_unitprice = (df['UnitPrice'] < (Q1_unitprice - 2.5 * IQR_unitprice)) | (df['UnitPrice'] > (Q3_unitprice + 2.5 * IQR_unitprice))
#
#     # Filtrar datos para observar registros con outliers en 'unitprice'
#     outliers_data_unitprice = df[outliers_unitprice]
#
#     # Box plot para 'quantity'
#     plt.figure(figsize=(8, 5))
#     sns.boxplot(x=df['Quantity'])
#     plt.title('Quantity BoxPlot')
#     plt.show()
#
#     # Calcular el rango intercuartílico (IQR) para 'quantity'
#     Q1_quantity = df['Quantity'].quantile(0.25)
#     Q3_quantity = df['Quantity'].quantile(0.75)
#     IQR_quantity = Q3_quantity - Q1_quantity
#
#     # Identificar outliers en 'quantity'
#     outliers_quantity = (df['Quantity'] < (Q1_quantity - 2.5 * IQR_quantity)) | (df['Quantity'] > (Q3_quantity + 2.5 * IQR_quantity))
#
#     # Filtrar datos para observar registros con outliers en 'quantity'
#     outliers_data_quantity = df[outliers_quantity]
#
#     # Paso 3: Discutir el Impacto Potencial
#
#     # Imprimir resumen de outliers en 'unitprice'
#     print("\nOutliers in 'unitprice':")
#     print(outliers_data_unitprice)
#
#     # Imprimir resumen de outliers en 'quantity'
#     print("\nOutliers in 'quantity':")
#     print(outliers_data_quantity)
#
#     # Puedes discutir el impacto potencial de estos outliers en el análisis en función del contexto de tus datos y objetivos.
#
#     # Por ejemplo, podrías decidir si eliminarlos, imputar valores o tomar medidas específicas según la naturaleza de tus datos y análisis.
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
#     Outliers in 'unitprice':
#     Empty DataFrame
#     Columns: [Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
#     Index: []
#
#     Outliers in 'quantity':
#     Empty DataFrame
#     Columns: [Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
#     Index: []
#
# ### Conclusion<a href="#Conclusion" class="anchor-link">¶</a>
#
# Before starting with this description of the project, I would like to
# let you know that we carry a couple of process to clean, perform and use
# data to this analysis.
#
# 1.  CLEANING DATA:
#
# Through this Exploratory Data Analysis we could find out that there was
# some missing and NaN values, so we could fix that by using Dropna
# function and fillna funtion. We delete three columns at the beggining of
# the process those were: Description, invoiceNo, StockCode by using drop
# funtion, but at the end we had to add Description and InvoiceDate column
# again because of graphs.
#
# 1.  CATEGORICAL VARIABLES
#
# We cleaned the dataset making sure that there wasn't any categorical
# values because we had to make some plots such as histogram plots, in
# this case we used unitprice column to make graphs and see how was going.
#
# 1.  IDENTIFYING OUTLIERS
#
# UnitPrice & Quantity were top on outlier with an potition of 2.5 that
# means there was dispersion on its points.
#
# 1.  MAKING PLOTS TO VARIABLES
#
# Monthly Sales Trends: January is the month of the best sales (in 2012)
# Top-Selling products and countries: Using groupby.() method we mixed 3
# columns (Quantity & Description), (Quantity & country) to make the
# Top-Selling Barplot. We found that there was 10 products with best sales
# around the globe. I'm going to provide a list of it:
#
# 1.  World War 2 Gliders Asstd Designs
# 2.  Jumbo Bag Red Retrospot
# 3.  Assorted Color Bird Ornament
# 4.  White Hanging Heart T-Light Holder
# 5.  Pack of 72 Retrospot Cake Cases
# 6.  PopCorn Holder
# 7.  Rabbit night Light
# 8.  Mini Paint Set Vintage
# 9.  Pack of 12 London Tissues
# 10. Pack of 60 pink Paisley Cake Cases
#
# where "World War 2 Gliders Asstd Designs has the most sales.
#
# WHAT WAS THOSE COUNTRIES?
#
# 1.  United Kingdom
# 2.  Netherlands
# 3.  EIRE
# 4.  Germany
# 5.  France
# 6.  Australia
# 7.  Sweden
# 8.  Switzerland
# 9.  Spain
# 10. Japan
#
# Where "United Kingdom" was the country with more sales.
#
# 1.  IDENTIFYING FREQUENTS MONTHS AND DAYS
#
# After I have researched, I had found out that the frequents months and
# days in this analysis were November and Wednesday.
